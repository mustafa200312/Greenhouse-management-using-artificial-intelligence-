# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

import cv2
from PIL import Image
import glob
import os
import re
from numba import cuda

import tensorflow as tf
from tensorflow.keras.layers import Input, Conv2D, Flatten, Dense, RepeatVector, LSTM, TimeDistributed,MaxPooling2D,Dropout
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.utils import img_to_array, load_img
from tensorflow.keras.preprocessing import image
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.models import Sequential,Model
from tensorflow.keras import layers, models

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score,mean_squared_error, mean_absolute_error

# %%
images_folder = 'images2/'

# %%
image_paths = glob.glob(os.path.join(images_folder, '*.png'))
sorted_list = sorted(image_paths, key=lambda x: int(re.search(r'image(\d+)_Tair', x).group(1)))

# %%
def rescale_image_to_array(files, target_size=(30, 30)):
    array = []
    for file in files:
        img = Image.open(file).convert('RGB').resize(target_size) 
        array.append(np.array(img))
    return np.array(array)

# %%
# def load_images_from_directory(files, target_size=(128, 128)):
#     images = []
#     for filename in files:
#         img = image.load_img(filename, target_size=target_size)
#         img_array = image.img_to_array(img)
#         images.append(img_array)   
#     return np.array(images)

# %%
images = rescale_image_to_array(sorted_list)

# %%
plt.imshow(images[0])
plt.show()

# %%
images.shape
# Out:
# (2497, 30, 30, 3)

# %%
from sklearn.metrics import r2_score

# %%
target = pd.read_csv('dataset_wind_rounded.csv')

# %%
target = target.to_numpy()

# %%
target.shape
# Out:
# (2497, 168)

# %%
X_train, X_test, y_train, y_test = train_test_split(
    images,  
    target,       
    test_size=0.2,    
    random_state=50,  
    shuffle=True      
)

# %%
scaler = StandardScaler()
y_train = scaler.fit_transform(y_train)
y_test = scaler.transform(y_test)

# %%
X_train = X_train.astype('float32') / 255.0
X_test = X_test.astype('float32') / 255.0

# %%
import numpy as np
from tensorflow.keras import layers, models
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.wrappers.scikit_learn import KerasRegressor

def create_model(num_conv_layers=2, filter_sizes=[32, 64, 64], kernel_size=(3,3),
                input_shape=(30,30,3), dense_units=64*64, dropout_rate=0.5):
    model = models.Sequential()
    
    model.add(layers.Conv2D(filter_sizes[0], kernel_size, activation='relu', input_shape=input_shape))
    model.add(layers.BatchNormalization())
    model.add(layers.MaxPooling2D((2, 2)))
    
    for i in range(1, num_conv_layers):
        model.add(layers.Conv2D(filter_sizes[i], kernel_size, activation='relu', padding='SAME'))
        model.add(layers.BatchNormalization())
        model.add(layers.MaxPooling2D((2, 2)))
    
    model.add(layers.Flatten())
    model.add(layers.Dense(dense_units, activation='relu'))
    model.add(layers.Dropout(dropout_rate))
    model.add(layers.Dense(168))  

    model.compile(optimizer=Adam(0.0001), loss='mean_squared_error', metrics=['mae'])
    
    return model

# %%
results = []

# %%
filters = [32, 64, 64, 128]
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
num_layers = 1
for filter_size in filters:
        model = create_model(filter_sizes=filters,num_conv_layers=num_layers)
        history = model.fit(
                X_train, y_train,
                epochs=100,
                batch_size=16,  
                validation_data=(X_test, y_test),
                callbacks=[early_stopping]
        )
        y_pred = model.predict(X_test)
        y_pred_train = model.predict(X_train)
        r2_test = r2_score(y_test, y_pred)
        r2_train = r2_score(y_train, y_pred_train)
        results.append((r2_train,r2_test, num_layers, model,history))
        num_layers += 1
# Out:
# Epoch 1/100
# 125/125 [==============================] - 7s 13ms/step - loss: 0.7282 - mae: 0.6674 - val_loss: 0.9833 - val_mae: 0.7956
# Epoch 2/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.5149 - mae: 0.5605 - val_loss: 0.8957 - val_mae: 0.7557
# Epoch 3/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.4317 - mae: 0.5130 - val_loss: 0.7611 - val_mae: 0.6884
# Epoch 4/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3947 - mae: 0.4893 - val_loss: 0.5985 - val_mae: 0.6036
# Epoch 5/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3758 - mae: 0.4768 - val_loss: 0.4314 - val_mae: 0.5122
# Epoch 6/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3611 - mae: 0.4664 - val_loss: 0.3882 - val_mae: 0.4831
# Epoch 7/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3496 - mae: 0.4578 - val_loss: 0.3743 - val_mae: 0.4745
# Epoch 8/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3405 - mae: 0.4519 - val_loss: 0.3430 - val_mae: 0.4519
# Epoch 9/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3337 - mae: 0.4459 - val_loss: 0.3290 - val_mae: 0.4419
# Epoch 10/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3262 - mae: 0.4404 - val_loss: 0.3035 - val_mae: 0.4225
# Epoch 11/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3199 - mae: 0.4359 - val_loss: 0.2954 - val_mae: 0.4160
# Epoch 12/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3133 - mae: 0.4310 - val_loss: 0.2875 - val_mae: 0.4103
# Epoch 13/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.3092 - mae: 0.4282 - val_loss: 0.2858 - val_mae: 0.4087
# Epoch 14/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3033 - mae: 0.4234 - val_loss: 0.2797 - val_mae: 0.4040
# Epoch 15/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2979 - mae: 0.4196 - val_loss: 0.2762 - val_mae: 0.4012
# Epoch 16/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2940 - mae: 0.4162 - val_loss: 0.2679 - val_mae: 0.3955
# Epoch 17/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2910 - mae: 0.4137 - val_loss: 0.2636 - val_mae: 0.3917
# Epoch 18/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2847 - mae: 0.4089 - val_loss: 0.2575 - val_mae: 0.3871
# Epoch 19/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.2802 - mae: 0.4050 - val_loss: 0.2561 - val_mae: 0.3850
# Epoch 20/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.2768 - mae: 0.4022 - val_loss: 0.2508 - val_mae: 0.3821
# Epoch 21/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.2725 - mae: 0.3984 - val_loss: 0.2470 - val_mae: 0.3773
# Epoch 22/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.2696 - mae: 0.3959 - val_loss: 0.2470 - val_mae: 0.3787
# Epoch 23/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.2662 - mae: 0.3930 - val_loss: 0.2388 - val_mae: 0.3696
# Epoch 24/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.2621 - mae: 0.3898 - val_loss: 0.2456 - val_mae: 0.3755
# Epoch 25/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2591 - mae: 0.3871 - val_loss: 0.2479 - val_mae: 0.3772
# Epoch 26/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2564 - mae: 0.3844 - val_loss: 0.2535 - val_mae: 0.3821
# Epoch 27/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2532 - mae: 0.3819 - val_loss: 0.2319 - val_mae: 0.3633
# Epoch 28/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2507 - mae: 0.3803 - val_loss: 0.2370 - val_mae: 0.3681
# Epoch 29/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2475 - mae: 0.3766 - val_loss: 0.2292 - val_mae: 0.3608
# Epoch 30/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2442 - mae: 0.3739 - val_loss: 0.2247 - val_mae: 0.3561
# Epoch 31/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2432 - mae: 0.3728 - val_loss: 0.2268 - val_mae: 0.3594
# Epoch 32/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2413 - mae: 0.3716 - val_loss: 0.2208 - val_mae: 0.3530
# Epoch 33/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.2392 - mae: 0.3695 - val_loss: 0.2213 - val_mae: 0.3538
# Epoch 34/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2376 - mae: 0.3688 - val_loss: 0.2163 - val_mae: 0.3484
# Epoch 35/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2337 - mae: 0.3653 - val_loss: 0.2170 - val_mae: 0.3487
# Epoch 36/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2335 - mae: 0.3648 - val_loss: 0.2211 - val_mae: 0.3527
# Epoch 37/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2310 - mae: 0.3634 - val_loss: 0.2144 - val_mae: 0.3479
# Epoch 38/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.2306 - mae: 0.3623 - val_loss: 0.2137 - val_mae: 0.3463
# Epoch 39/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2292 - mae: 0.3614 - val_loss: 0.2163 - val_mae: 0.3488
# Epoch 40/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2260 - mae: 0.3589 - val_loss: 0.2198 - val_mae: 0.3519
# Epoch 41/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2254 - mae: 0.3587 - val_loss: 0.2063 - val_mae: 0.3397
# Epoch 42/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2233 - mae: 0.3567 - val_loss: 0.2100 - val_mae: 0.3440
# Epoch 43/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.2217 - mae: 0.3551 - val_loss: 0.2101 - val_mae: 0.3435
# Epoch 44/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2214 - mae: 0.3545 - val_loss: 0.2053 - val_mae: 0.3390
# Epoch 45/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2198 - mae: 0.3532 - val_loss: 0.2073 - val_mae: 0.3402
# Epoch 46/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2184 - mae: 0.3519 - val_loss: 0.2072 - val_mae: 0.3428
# Epoch 47/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2156 - mae: 0.3497 - val_loss: 0.2045 - val_mae: 0.3385
# Epoch 48/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2132 - mae: 0.3474 - val_loss: 0.2054 - val_mae: 0.3380
# Epoch 49/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2118 - mae: 0.3463 - val_loss: 0.1996 - val_mae: 0.3341
# Epoch 50/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2107 - mae: 0.3458 - val_loss: 0.1986 - val_mae: 0.3333
# Epoch 51/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2098 - mae: 0.3446 - val_loss: 0.2023 - val_mae: 0.3360
# Epoch 52/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2073 - mae: 0.3423 - val_loss: 0.2012 - val_mae: 0.3363
# Epoch 53/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2069 - mae: 0.3417 - val_loss: 0.1963 - val_mae: 0.3305
# Epoch 54/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2057 - mae: 0.3411 - val_loss: 0.1942 - val_mae: 0.3301
# Epoch 55/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2037 - mae: 0.3396 - val_loss: 0.1893 - val_mae: 0.3233
# Epoch 56/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2021 - mae: 0.3381 - val_loss: 0.1928 - val_mae: 0.3287
# Epoch 57/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2010 - mae: 0.3371 - val_loss: 0.1956 - val_mae: 0.3316
# Epoch 58/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2000 - mae: 0.3366 - val_loss: 0.1891 - val_mae: 0.3251
# Epoch 59/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1979 - mae: 0.3344 - val_loss: 0.1858 - val_mae: 0.3225
# Epoch 60/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1981 - mae: 0.3347 - val_loss: 0.1860 - val_mae: 0.3223
# Epoch 61/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1966 - mae: 0.3332 - val_loss: 0.1897 - val_mae: 0.3245
# Epoch 62/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1964 - mae: 0.3333 - val_loss: 0.1799 - val_mae: 0.3150
# Epoch 63/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1930 - mae: 0.3301 - val_loss: 0.1833 - val_mae: 0.3192
# Epoch 64/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1934 - mae: 0.3307 - val_loss: 0.1799 - val_mae: 0.3147
# Epoch 65/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1924 - mae: 0.3299 - val_loss: 0.1873 - val_mae: 0.3219
# Epoch 66/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1887 - mae: 0.3257 - val_loss: 0.1817 - val_mae: 0.3185
# Epoch 67/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1885 - mae: 0.3259 - val_loss: 0.1785 - val_mae: 0.3143
# Epoch 68/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1881 - mae: 0.3253 - val_loss: 0.1756 - val_mae: 0.3098
# Epoch 69/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1860 - mae: 0.3239 - val_loss: 0.1715 - val_mae: 0.3078
# Epoch 70/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1855 - mae: 0.3230 - val_loss: 0.1763 - val_mae: 0.3120
# Epoch 71/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1844 - mae: 0.3227 - val_loss: 0.1688 - val_mae: 0.3049
# Epoch 72/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1842 - mae: 0.3220 - val_loss: 0.1835 - val_mae: 0.3195
# Epoch 73/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1843 - mae: 0.3225 - val_loss: 0.1700 - val_mae: 0.3057
# Epoch 74/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1820 - mae: 0.3203 - val_loss: 0.1697 - val_mae: 0.3049
# Epoch 75/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1800 - mae: 0.3184 - val_loss: 0.1686 - val_mae: 0.3038
# Epoch 76/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1803 - mae: 0.3189 - val_loss: 0.1729 - val_mae: 0.3076
# Epoch 77/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1803 - mae: 0.3188 - val_loss: 0.1679 - val_mae: 0.3029
# Epoch 78/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1782 - mae: 0.3163 - val_loss: 0.1687 - val_mae: 0.3041
# Epoch 79/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1778 - mae: 0.3160 - val_loss: 0.1754 - val_mae: 0.3119
# Epoch 80/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1759 - mae: 0.3140 - val_loss: 0.1731 - val_mae: 0.3089
# Epoch 81/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1784 - mae: 0.3174 - val_loss: 0.1705 - val_mae: 0.3068
# Epoch 82/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1768 - mae: 0.3156 - val_loss: 0.1634 - val_mae: 0.2984
# Epoch 83/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1741 - mae: 0.3130 - val_loss: 0.1605 - val_mae: 0.2966
# Epoch 84/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1736 - mae: 0.3126 - val_loss: 0.1721 - val_mae: 0.3095
# Epoch 85/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1739 - mae: 0.3126 - val_loss: 0.1782 - val_mae: 0.3155
# Epoch 86/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1721 - mae: 0.3109 - val_loss: 0.1632 - val_mae: 0.2996
# Epoch 87/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1716 - mae: 0.3105 - val_loss: 0.1665 - val_mae: 0.3053
# Epoch 88/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1712 - mae: 0.3102 - val_loss: 0.1585 - val_mae: 0.2937
# Epoch 89/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1712 - mae: 0.3102 - val_loss: 0.1619 - val_mae: 0.2974
# Epoch 90/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1705 - mae: 0.3096 - val_loss: 0.1586 - val_mae: 0.2946
# Epoch 91/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1687 - mae: 0.3085 - val_loss: 0.1658 - val_mae: 0.3038
# Epoch 92/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1698 - mae: 0.3090 - val_loss: 0.1661 - val_mae: 0.3039
# Epoch 93/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1676 - mae: 0.3069 - val_loss: 0.1551 - val_mae: 0.2903
# Epoch 94/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1689 - mae: 0.3084 - val_loss: 0.1628 - val_mae: 0.3002
# Epoch 95/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1680 - mae: 0.3074 - val_loss: 0.1632 - val_mae: 0.3025
# Epoch 96/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1669 - mae: 0.3065 - val_loss: 0.1541 - val_mae: 0.2904
# Epoch 97/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1684 - mae: 0.3074 - val_loss: 0.1644 - val_mae: 0.3041
# Epoch 98/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1674 - mae: 0.3071 - val_loss: 0.1533 - val_mae: 0.2888
# Epoch 99/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1665 - mae: 0.3060 - val_loss: 0.1525 - val_mae: 0.2875
# Epoch 100/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1653 - mae: 0.3047 - val_loss: 0.1537 - val_mae: 0.2893
# 16/16 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 1ms/step
# Epoch 1/100
# 125/125 [==============================] - 1s 8ms/step - loss: 0.8643 - mae: 0.7124 - val_loss: 1.0596 - val_mae: 0.8327
# Epoch 2/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.5021 - mae: 0.5546 - val_loss: 1.2268 - val_mae: 0.8872
# Epoch 3/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.4319 - mae: 0.5137 - val_loss: 1.0278 - val_mae: 0.8089
# Epoch 4/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.4006 - mae: 0.4935 - val_loss: 0.5761 - val_mae: 0.6030
# Epoch 5/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3803 - mae: 0.4802 - val_loss: 0.3851 - val_mae: 0.4904
# Epoch 6/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3651 - mae: 0.4695 - val_loss: 0.3191 - val_mae: 0.4404
# Epoch 7/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3538 - mae: 0.4620 - val_loss: 0.3090 - val_mae: 0.4301
# Epoch 8/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3449 - mae: 0.4557 - val_loss: 0.2870 - val_mae: 0.4129
# Epoch 9/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3354 - mae: 0.4493 - val_loss: 0.3172 - val_mae: 0.4356
# Epoch 10/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3279 - mae: 0.4439 - val_loss: 0.2894 - val_mae: 0.4130
# Epoch 11/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3234 - mae: 0.4406 - val_loss: 0.2960 - val_mae: 0.4204
# Epoch 12/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3193 - mae: 0.4377 - val_loss: 0.2818 - val_mae: 0.4097
# Epoch 13/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3161 - mae: 0.4349 - val_loss: 0.2819 - val_mae: 0.4080
# Epoch 14/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3124 - mae: 0.4325 - val_loss: 0.2813 - val_mae: 0.4087
# Epoch 15/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3060 - mae: 0.4277 - val_loss: 0.2811 - val_mae: 0.4118
# Epoch 16/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3038 - mae: 0.4260 - val_loss: 0.2667 - val_mae: 0.4004
# Epoch 17/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2992 - mae: 0.4227 - val_loss: 0.2534 - val_mae: 0.3869
# Epoch 18/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2922 - mae: 0.4172 - val_loss: 0.2525 - val_mae: 0.3848
# Epoch 19/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2915 - mae: 0.4168 - val_loss: 0.2962 - val_mae: 0.4215
# Epoch 20/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2866 - mae: 0.4128 - val_loss: 0.2665 - val_mae: 0.4002
# Epoch 21/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2836 - mae: 0.4102 - val_loss: 0.2744 - val_mae: 0.4021
# Epoch 22/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2801 - mae: 0.4075 - val_loss: 0.2570 - val_mae: 0.3898
# Epoch 23/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2753 - mae: 0.4035 - val_loss: 0.2772 - val_mae: 0.4103
# Epoch 24/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2727 - mae: 0.4015 - val_loss: 0.2615 - val_mae: 0.3950
# Epoch 25/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2692 - mae: 0.3987 - val_loss: 0.2722 - val_mae: 0.3972
# Epoch 26/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2678 - mae: 0.3980 - val_loss: 0.2373 - val_mae: 0.3720
# Epoch 27/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2635 - mae: 0.3944 - val_loss: 0.2836 - val_mae: 0.4148
# Epoch 28/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2619 - mae: 0.3938 - val_loss: 0.2531 - val_mae: 0.3841
# Epoch 29/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2584 - mae: 0.3903 - val_loss: 0.2498 - val_mae: 0.3854
# Epoch 30/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2555 - mae: 0.3879 - val_loss: 0.2343 - val_mae: 0.3705
# Epoch 31/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2528 - mae: 0.3854 - val_loss: 0.2442 - val_mae: 0.3778
# Epoch 32/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2513 - mae: 0.3849 - val_loss: 0.2353 - val_mae: 0.3710
# Epoch 33/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2490 - mae: 0.3831 - val_loss: 0.2365 - val_mae: 0.3702
# Epoch 34/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2450 - mae: 0.3800 - val_loss: 0.2151 - val_mae: 0.3523
# Epoch 35/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2445 - mae: 0.3792 - val_loss: 0.2498 - val_mae: 0.3828
# Epoch 36/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2429 - mae: 0.3777 - val_loss: 0.2198 - val_mae: 0.3573
# Epoch 37/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2395 - mae: 0.3743 - val_loss: 0.2276 - val_mae: 0.3635
# Epoch 38/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2391 - mae: 0.3745 - val_loss: 0.2202 - val_mae: 0.3587
# Epoch 39/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2350 - mae: 0.3714 - val_loss: 0.2150 - val_mae: 0.3534
# Epoch 40/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2350 - mae: 0.3706 - val_loss: 0.2532 - val_mae: 0.3824
# Epoch 41/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2330 - mae: 0.3696 - val_loss: 0.2466 - val_mae: 0.3841
# Epoch 42/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2278 - mae: 0.3646 - val_loss: 0.2644 - val_mae: 0.3939
# Epoch 43/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2273 - mae: 0.3646 - val_loss: 0.2444 - val_mae: 0.3776
# Epoch 44/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2259 - mae: 0.3635 - val_loss: 0.2222 - val_mae: 0.3582
# Epoch 45/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2223 - mae: 0.3605 - val_loss: 0.2591 - val_mae: 0.3874
# Epoch 46/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2218 - mae: 0.3596 - val_loss: 0.2051 - val_mae: 0.3439
# Epoch 47/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2222 - mae: 0.3603 - val_loss: 0.2458 - val_mae: 0.3763
# Epoch 48/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2227 - mae: 0.3611 - val_loss: 0.2221 - val_mae: 0.3574
# Epoch 49/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2174 - mae: 0.3564 - val_loss: 0.1977 - val_mae: 0.3377
# Epoch 50/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2189 - mae: 0.3574 - val_loss: 0.2048 - val_mae: 0.3423
# Epoch 51/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2148 - mae: 0.3540 - val_loss: 0.1963 - val_mae: 0.3354
# Epoch 52/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2141 - mae: 0.3529 - val_loss: 0.2123 - val_mae: 0.3499
# Epoch 53/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2128 - mae: 0.3520 - val_loss: 0.2231 - val_mae: 0.3539
# Epoch 54/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2132 - mae: 0.3522 - val_loss: 0.2577 - val_mae: 0.3892
# Epoch 55/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2153 - mae: 0.3544 - val_loss: 0.2231 - val_mae: 0.3623
# Epoch 56/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2107 - mae: 0.3501 - val_loss: 0.2035 - val_mae: 0.3412
# Epoch 57/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2086 - mae: 0.3483 - val_loss: 0.2224 - val_mae: 0.3633
# Epoch 58/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2065 - mae: 0.3465 - val_loss: 0.2018 - val_mae: 0.3396
# Epoch 59/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2064 - mae: 0.3471 - val_loss: 0.2112 - val_mae: 0.3485
# Epoch 60/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2065 - mae: 0.3468 - val_loss: 0.1833 - val_mae: 0.3255
# Epoch 61/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2049 - mae: 0.3452 - val_loss: 0.1799 - val_mae: 0.3196
# Epoch 62/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2024 - mae: 0.3422 - val_loss: 0.2205 - val_mae: 0.3581
# Epoch 63/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2005 - mae: 0.3410 - val_loss: 0.2096 - val_mae: 0.3483
# Epoch 64/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2028 - mae: 0.3427 - val_loss: 0.2291 - val_mae: 0.3618
# Epoch 65/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2017 - mae: 0.3426 - val_loss: 0.1968 - val_mae: 0.3364
# Epoch 66/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2012 - mae: 0.3417 - val_loss: 0.2032 - val_mae: 0.3408
# Epoch 67/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1984 - mae: 0.3389 - val_loss: 0.2054 - val_mae: 0.3448
# Epoch 68/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1959 - mae: 0.3364 - val_loss: 0.2204 - val_mae: 0.3528
# Epoch 69/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1976 - mae: 0.3381 - val_loss: 0.1745 - val_mae: 0.3143
# Epoch 70/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1976 - mae: 0.3382 - val_loss: 0.1876 - val_mae: 0.3268
# Epoch 71/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1973 - mae: 0.3381 - val_loss: 0.1919 - val_mae: 0.3321
# Epoch 72/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1940 - mae: 0.3349 - val_loss: 0.2895 - val_mae: 0.4138
# Epoch 73/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1932 - mae: 0.3342 - val_loss: 0.2534 - val_mae: 0.3841
# Epoch 74/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1948 - mae: 0.3358 - val_loss: 0.2118 - val_mae: 0.3474
# Epoch 75/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1930 - mae: 0.3342 - val_loss: 0.2096 - val_mae: 0.3462
# Epoch 76/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1924 - mae: 0.3337 - val_loss: 0.1917 - val_mae: 0.3271
# Epoch 77/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1915 - mae: 0.3324 - val_loss: 0.1969 - val_mae: 0.3353
# Epoch 78/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1898 - mae: 0.3313 - val_loss: 0.1875 - val_mae: 0.3282
# Epoch 79/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1905 - mae: 0.3317 - val_loss: 0.1790 - val_mae: 0.3191
# 16/16 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 1ms/step
# Epoch 1/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.8086 - mae: 0.7009 - val_loss: 1.1761 - val_mae: 0.8795
# Epoch 2/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.4609 - mae: 0.5310 - val_loss: 1.2635 - val_mae: 0.9151
# Epoch 3/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.3864 - mae: 0.4853 - val_loss: 1.0989 - val_mae: 0.8523
# Epoch 4/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3512 - mae: 0.4605 - val_loss: 0.6303 - val_mae: 0.6360
# Epoch 5/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.3304 - mae: 0.4456 - val_loss: 0.3648 - val_mae: 0.4769
# Epoch 6/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.3147 - mae: 0.4344 - val_loss: 0.3030 - val_mae: 0.4254
# Epoch 7/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2992 - mae: 0.4232 - val_loss: 0.2778 - val_mae: 0.4064
# Epoch 8/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.2878 - mae: 0.4144 - val_loss: 0.2781 - val_mae: 0.4064
# Epoch 9/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.2776 - mae: 0.4068 - val_loss: 0.2538 - val_mae: 0.3882
# Epoch 10/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2689 - mae: 0.4002 - val_loss: 0.2680 - val_mae: 0.3989
# Epoch 11/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2620 - mae: 0.3949 - val_loss: 0.2810 - val_mae: 0.4086
# Epoch 12/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2536 - mae: 0.3883 - val_loss: 0.2474 - val_mae: 0.3820
# Epoch 13/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2475 - mae: 0.3832 - val_loss: 0.2415 - val_mae: 0.3796
# Epoch 14/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2405 - mae: 0.3773 - val_loss: 0.2454 - val_mae: 0.3813
# Epoch 15/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2328 - mae: 0.3710 - val_loss: 0.2533 - val_mae: 0.3855
# Epoch 16/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2258 - mae: 0.3651 - val_loss: 0.2634 - val_mae: 0.3975
# Epoch 17/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2185 - mae: 0.3587 - val_loss: 0.2556 - val_mae: 0.3911
# Epoch 18/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2128 - mae: 0.3540 - val_loss: 0.2303 - val_mae: 0.3681
# Epoch 19/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.2059 - mae: 0.3474 - val_loss: 0.2803 - val_mae: 0.4103
# Epoch 20/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2008 - mae: 0.3426 - val_loss: 0.2355 - val_mae: 0.3741
# Epoch 21/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1954 - mae: 0.3379 - val_loss: 0.1928 - val_mae: 0.3330
# Epoch 22/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1894 - mae: 0.3321 - val_loss: 0.2099 - val_mae: 0.3494
# Epoch 23/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1844 - mae: 0.3274 - val_loss: 0.2126 - val_mae: 0.3540
# Epoch 24/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1811 - mae: 0.3242 - val_loss: 0.2098 - val_mae: 0.3517
# Epoch 25/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1755 - mae: 0.3189 - val_loss: 0.2081 - val_mae: 0.3502
# Epoch 26/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1724 - mae: 0.3157 - val_loss: 0.2094 - val_mae: 0.3510
# Epoch 27/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1680 - mae: 0.3117 - val_loss: 0.1903 - val_mae: 0.3309
# Epoch 28/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1660 - mae: 0.3095 - val_loss: 0.2323 - val_mae: 0.3731
# Epoch 29/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1623 - mae: 0.3057 - val_loss: 0.1820 - val_mae: 0.3242
# Epoch 30/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1601 - mae: 0.3036 - val_loss: 0.1908 - val_mae: 0.3307
# Epoch 31/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1578 - mae: 0.3010 - val_loss: 0.1959 - val_mae: 0.3390
# Epoch 32/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1536 - mae: 0.2961 - val_loss: 0.2456 - val_mae: 0.3828
# Epoch 33/100
# 125/125 [==============================] - 1s 12ms/step - loss: 0.1510 - mae: 0.2937 - val_loss: 0.1700 - val_mae: 0.3105
# Epoch 34/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1508 - mae: 0.2933 - val_loss: 0.1763 - val_mae: 0.3190
# Epoch 35/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1485 - mae: 0.2911 - val_loss: 0.1661 - val_mae: 0.3076
# Epoch 36/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1461 - mae: 0.2887 - val_loss: 0.2535 - val_mae: 0.3923
# Epoch 37/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1444 - mae: 0.2869 - val_loss: 0.1869 - val_mae: 0.3295
# Epoch 38/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1429 - mae: 0.2848 - val_loss: 0.1721 - val_mae: 0.3132
# Epoch 39/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1405 - mae: 0.2828 - val_loss: 0.1525 - val_mae: 0.2915
# Epoch 40/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1382 - mae: 0.2800 - val_loss: 0.1819 - val_mae: 0.3235
# Epoch 41/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1388 - mae: 0.2805 - val_loss: 0.1842 - val_mae: 0.3276
# Epoch 42/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1355 - mae: 0.2768 - val_loss: 0.1709 - val_mae: 0.3121
# Epoch 43/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1344 - mae: 0.2757 - val_loss: 0.1802 - val_mae: 0.3239
# Epoch 44/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1324 - mae: 0.2736 - val_loss: 0.1647 - val_mae: 0.3041
# Epoch 45/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1326 - mae: 0.2740 - val_loss: 0.1932 - val_mae: 0.3356
# Epoch 46/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1308 - mae: 0.2723 - val_loss: 0.1556 - val_mae: 0.2946
# Epoch 47/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1303 - mae: 0.2713 - val_loss: 0.1680 - val_mae: 0.3101
# Epoch 48/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1288 - mae: 0.2699 - val_loss: 0.1496 - val_mae: 0.2886
# Epoch 49/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1280 - mae: 0.2683 - val_loss: 0.2140 - val_mae: 0.3554
# Epoch 50/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1263 - mae: 0.2669 - val_loss: 0.1600 - val_mae: 0.3018
# Epoch 51/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1265 - mae: 0.2675 - val_loss: 0.1917 - val_mae: 0.3349
# Epoch 52/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1248 - mae: 0.2649 - val_loss: 0.2132 - val_mae: 0.3507
# Epoch 53/100
# 125/125 [==============================] - 1s 5ms/step - loss: 0.1244 - mae: 0.2647 - val_loss: 0.1597 - val_mae: 0.3001
# Epoch 54/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1234 - mae: 0.2632 - val_loss: 0.1638 - val_mae: 0.3044
# Epoch 55/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1223 - mae: 0.2620 - val_loss: 0.1609 - val_mae: 0.3023
# Epoch 56/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1217 - mae: 0.2619 - val_loss: 0.2045 - val_mae: 0.3470
# Epoch 57/100
# 125/125 [==============================] - 2s 19ms/step - loss: 0.1206 - mae: 0.2601 - val_loss: 0.1325 - val_mae: 0.2698
# Epoch 58/100
# 125/125 [==============================] - 2s 12ms/step - loss: 0.1199 - mae: 0.2592 - val_loss: 0.2195 - val_mae: 0.3532
# Epoch 59/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1182 - mae: 0.2578 - val_loss: 0.1477 - val_mae: 0.2872
# Epoch 60/100
# 125/125 [==============================] - 2s 15ms/step - loss: 0.1177 - mae: 0.2570 - val_loss: 0.1416 - val_mae: 0.2828
# Epoch 61/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1169 - mae: 0.2563 - val_loss: 0.1438 - val_mae: 0.2846
# Epoch 62/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.1185 - mae: 0.2584 - val_loss: 0.1688 - val_mae: 0.3110
# Epoch 63/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1157 - mae: 0.2554 - val_loss: 0.1594 - val_mae: 0.3039
# Epoch 64/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1152 - mae: 0.2544 - val_loss: 0.1423 - val_mae: 0.2811
# Epoch 65/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1149 - mae: 0.2539 - val_loss: 0.1912 - val_mae: 0.3309
# Epoch 66/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.1135 - mae: 0.2525 - val_loss: 0.1653 - val_mae: 0.3080
# Epoch 67/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.1131 - mae: 0.2521 - val_loss: 0.1457 - val_mae: 0.2863
# 16/16 [==============================] - 0s 4ms/step
# 63/63 [==============================] - 0s 2ms/step
# Epoch 1/100
# 125/125 [==============================] - 2s 13ms/step - loss: 0.7207 - mae: 0.6643 - val_loss: 1.0513 - val_mae: 0.8223
# Epoch 2/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.4193 - mae: 0.5055 - val_loss: 1.0830 - val_mae: 0.8354
# Epoch 3/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.3582 - mae: 0.4652 - val_loss: 1.0766 - val_mae: 0.8217
# Epoch 4/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3284 - mae: 0.4438 - val_loss: 0.8724 - val_mae: 0.7221
# Epoch 5/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.3064 - mae: 0.4276 - val_loss: 0.4424 - val_mae: 0.5241
# Epoch 6/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2895 - mae: 0.4152 - val_loss: 0.3050 - val_mae: 0.4329
# Epoch 7/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2759 - mae: 0.4049 - val_loss: 0.2766 - val_mae: 0.4074
# Epoch 8/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.2659 - mae: 0.3970 - val_loss: 0.2794 - val_mae: 0.4097
# Epoch 9/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.2561 - mae: 0.3895 - val_loss: 0.2610 - val_mae: 0.3950
# Epoch 10/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2493 - mae: 0.3843 - val_loss: 0.2583 - val_mae: 0.3914
# Epoch 11/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.2406 - mae: 0.3769 - val_loss: 0.2688 - val_mae: 0.4024
# Epoch 12/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.2325 - mae: 0.3702 - val_loss: 0.2362 - val_mae: 0.3721
# Epoch 13/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2263 - mae: 0.3650 - val_loss: 0.3283 - val_mae: 0.4383
# Epoch 14/100
# 125/125 [==============================] - 1s 10ms/step - loss: 0.2173 - mae: 0.3572 - val_loss: 0.2820 - val_mae: 0.4117
# Epoch 15/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2093 - mae: 0.3500 - val_loss: 0.2560 - val_mae: 0.3940
# Epoch 16/100
# 125/125 [==============================] - 1s 11ms/step - loss: 0.2022 - mae: 0.3437 - val_loss: 0.2742 - val_mae: 0.4060
# Epoch 17/100
# 125/125 [==============================] - 1s 9ms/step - loss: 0.1956 - mae: 0.3374 - val_loss: 0.3533 - val_mae: 0.4705
# Epoch 18/100
# 125/125 [==============================] - 1s 7ms/step - loss: 0.1895 - mae: 0.3318 - val_loss: 0.2715 - val_mae: 0.4011
# Epoch 19/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1852 - mae: 0.3276 - val_loss: 0.3130 - val_mae: 0.4351
# Epoch 20/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1774 - mae: 0.3201 - val_loss: 0.2282 - val_mae: 0.3678
# Epoch 21/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1744 - mae: 0.3171 - val_loss: 0.2165 - val_mae: 0.3533
# Epoch 22/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1694 - mae: 0.3121 - val_loss: 0.1859 - val_mae: 0.3272
# Epoch 23/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1645 - mae: 0.3068 - val_loss: 0.2074 - val_mae: 0.3500
# Epoch 24/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1627 - mae: 0.3053 - val_loss: 0.2085 - val_mae: 0.3497
# Epoch 25/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1597 - mae: 0.3025 - val_loss: 0.1954 - val_mae: 0.3373
# Epoch 26/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1548 - mae: 0.2972 - val_loss: 0.2503 - val_mae: 0.3888
# Epoch 27/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1526 - mae: 0.2948 - val_loss: 0.1786 - val_mae: 0.3202
# Epoch 28/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1507 - mae: 0.2929 - val_loss: 0.1764 - val_mae: 0.3184
# Epoch 29/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1464 - mae: 0.2883 - val_loss: 0.1755 - val_mae: 0.3170
# Epoch 30/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1464 - mae: 0.2880 - val_loss: 0.1806 - val_mae: 0.3219
# Epoch 31/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1441 - mae: 0.2861 - val_loss: 0.1967 - val_mae: 0.3349
# Epoch 32/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1423 - mae: 0.2839 - val_loss: 0.1705 - val_mae: 0.3117
# Epoch 33/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1413 - mae: 0.2828 - val_loss: 0.2187 - val_mae: 0.3576
# Epoch 34/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1382 - mae: 0.2792 - val_loss: 0.1574 - val_mae: 0.2981
# Epoch 35/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1380 - mae: 0.2789 - val_loss: 0.1620 - val_mae: 0.3025
# Epoch 36/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1363 - mae: 0.2771 - val_loss: 0.1619 - val_mae: 0.3024
# Epoch 37/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1339 - mae: 0.2743 - val_loss: 0.1816 - val_mae: 0.3239
# Epoch 38/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1335 - mae: 0.2739 - val_loss: 0.2057 - val_mae: 0.3484
# Epoch 39/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1310 - mae: 0.2717 - val_loss: 0.1833 - val_mae: 0.3263
# Epoch 40/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1308 - mae: 0.2714 - val_loss: 0.1828 - val_mae: 0.3264
# Epoch 41/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1286 - mae: 0.2684 - val_loss: 0.1845 - val_mae: 0.3282
# Epoch 42/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1294 - mae: 0.2697 - val_loss: 0.1525 - val_mae: 0.2929
# Epoch 43/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1269 - mae: 0.2668 - val_loss: 0.1543 - val_mae: 0.2967
# Epoch 44/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1254 - mae: 0.2650 - val_loss: 0.1683 - val_mae: 0.3080
# Epoch 45/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1249 - mae: 0.2640 - val_loss: 0.1606 - val_mae: 0.3014
# Epoch 46/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1231 - mae: 0.2622 - val_loss: 0.2065 - val_mae: 0.3442
# Epoch 47/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1242 - mae: 0.2633 - val_loss: 0.1701 - val_mae: 0.3130
# Epoch 48/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1215 - mae: 0.2604 - val_loss: 0.1829 - val_mae: 0.3240
# Epoch 49/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1207 - mae: 0.2599 - val_loss: 0.2546 - val_mae: 0.3921
# Epoch 50/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1201 - mae: 0.2588 - val_loss: 0.1545 - val_mae: 0.2956
# Epoch 51/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1199 - mae: 0.2587 - val_loss: 0.1491 - val_mae: 0.2903
# Epoch 52/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1185 - mae: 0.2572 - val_loss: 0.1510 - val_mae: 0.2922
# Epoch 53/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1173 - mae: 0.2559 - val_loss: 0.1796 - val_mae: 0.3215
# Epoch 54/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1166 - mae: 0.2550 - val_loss: 0.1556 - val_mae: 0.2957
# Epoch 55/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1148 - mae: 0.2522 - val_loss: 0.1677 - val_mae: 0.3111
# Epoch 56/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1152 - mae: 0.2534 - val_loss: 0.1903 - val_mae: 0.3297
# Epoch 57/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1140 - mae: 0.2519 - val_loss: 0.1548 - val_mae: 0.2952
# Epoch 58/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1147 - mae: 0.2527 - val_loss: 0.1565 - val_mae: 0.2970
# Epoch 59/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1129 - mae: 0.2503 - val_loss: 0.1441 - val_mae: 0.2826
# Epoch 60/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1114 - mae: 0.2489 - val_loss: 0.1813 - val_mae: 0.3264
# Epoch 61/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1115 - mae: 0.2489 - val_loss: 0.1737 - val_mae: 0.3163
# Epoch 62/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1105 - mae: 0.2478 - val_loss: 0.1617 - val_mae: 0.3037
# Epoch 63/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1093 - mae: 0.2466 - val_loss: 0.1845 - val_mae: 0.3278
# Epoch 64/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1089 - mae: 0.2457 - val_loss: 0.1879 - val_mae: 0.3265
# Epoch 65/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1089 - mae: 0.2461 - val_loss: 0.1653 - val_mae: 0.3073
# Epoch 66/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1076 - mae: 0.2444 - val_loss: 0.1791 - val_mae: 0.3232
# Epoch 67/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1082 - mae: 0.2453 - val_loss: 0.1657 - val_mae: 0.3100
# Epoch 68/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1070 - mae: 0.2441 - val_loss: 0.1818 - val_mae: 0.3261
# Epoch 69/100
# 125/125 [==============================] - 1s 6ms/step - loss: 0.1055 - mae: 0.2419 - val_loss: 0.1532 - val_mae: 0.2942
# 16/16 [==============================] - 0s 2ms/step
# 63/63 [==============================] - 0s 2ms/step

# %%
results
# Out:
# [(0.8629001504852676,
#   0.8507200764816124,
#   1,
#   <keras.engine.sequential.Sequential at 0x1ccd5aed070>,
#   <keras.callbacks.History at 0x1ccd864cfa0>),
#  (0.8450422933143125,
#   0.83023740016086,
#   2,
#   <keras.engine.sequential.Sequential at 0x1ccd900cc40>,
#   <keras.callbacks.History at 0x1ccd8fbc130>),
#  (0.8954005004968432,
#   0.8712816149246905,
#   3,
#   <keras.engine.sequential.Sequential at 0x1ccd906e880>,
#   <keras.callbacks.History at 0x1ccf0e97070>),
#  (0.8785990878022807,
#   0.860184269880613,
#   4,
#   <keras.engine.sequential.Sequential at 0x1cd15658bb0>,
#   <keras.callbacks.History at 0x1cd19e997f0>)]

# %%
history = results[2][4]
model = results[2][3]

# %%
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
with tf.device('/CPU:0'):
    y_pred_train = model.predict(X_train)
    y_pred_test = model.predict(X_test)
# Out:
# 63/63 [==============================] - 1s 12ms/step
# 16/16 [==============================] - 0s 11ms/step

# %%
print("R2 score for training data:", r2_score(y_train, y_pred_train))
print("R2 score for testing data:", r2_score(y_test, y_pred_test))
# Out:
# R2 score for training data: 0.8954010430638406
# R2 score for testing data: 0.8712828236877628

# %%
print("MSE score for testing data:", mean_squared_error(y_train, y_pred_train))
print("MAE score for testing data:", mean_absolute_error(y_test, y_pred_test))
# Out:
# MSE score for testing data: 0.10459895693615939
# MAE score for testing data: 0.2698333949898653

# %%
model.save('models\model_wind_0.h5')

# %%
y_pred_test_true = scaler.inverse_transform(y_pred_test)
y_test_true = scaler.inverse_transform(y_test)

# %%
plt.figure(figsize=(10, 5))
plt.plot(y_test_true.flatten()[:288], label='True Values')
plt.plot(y_pred_test_true.flatten()[:288], label='Predicted Values')
plt.xlabel('Sample Index')
plt.title('True vs Predicted Values')
plt.ylabel('Value')
plt.legend()
plt.show()

# %% [markdown]
# # Visualize CONVS

# %%
from tensorflow.keras.models import load_model
model = load_model('models/model_wind_0.h5')

# %%
for layer in model.layers:
    print(layer.name)
# Out:
# conv2d_3
# batch_normalization_3
# max_pooling2d_3
# conv2d_4
# batch_normalization_4
# max_pooling2d_4
# conv2d_5
# batch_normalization_5
# max_pooling2d_5
# flatten_2
# dense_4
# dropout_2
# dense_5

# %%
from skimage.transform import resize

input1 = X_test[0]
layer_name = 'conv2d_3' 
layer = model.get_layer(layer_name)

activation_model = Model(inputs=model.input, outputs=layer.output)
image_input = np.expand_dims(input1, axis=0)
activations = activation_model.predict(image_input)

activa = activations[0, :, :, 1]
activa_rescaled = resize(activa, (1600, 1600), anti_aliasing=True)
input1 = rescale_image_to_array([sorted_list[0]],(1600,1600))[0]
fig, ax = plt.subplots(1, 2, figsize=(15, 7))

ax[0].imshow(input1)
ax[0].set_title('Base Image')
ax[1].imshow(input1)
ax[1].imshow(activa_rescaled, cmap='viridis', alpha=0.75)
ax[1].set_title('Overlayed Activation')
plt.show()
# Out:
# 1/1 [==============================] - 0s 28ms/step
